# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Kelvi\AppData\Local\Programs\Python\Python313\python.exe

# %%
pip show tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: tensorflow

# %%
# !pip install tensorflow

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Kelvi\AppData\Local\Programs\Python\Python313\python.exe

# %%
# !pip install ipykernel
python -m ipykernel install --user --name tensorflow312 --display-name "Python 3.12 (TF)"
# Out:
# ...
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached debugpy-1.8.14-cp312-cp312-win_amd64.whl.metadata (1.4 kB)
# ...
#   Using cached ipython-9.3.0-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached jupyter_core-5.8.1-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached psutil-7.0.0-cp37-abi3-win_amd64.whl.metadata (23 kB)
# ...
#   Using cached pyzmq-27.0.0-cp312-abi3-win_amd64.whl.metadata (6.0 kB)
# ...
#   Using cached tornado-6.5.1-cp39-abi3-win_amd64.whl.metadata (2.9 kB)
# ...
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# ...

# %%
python -m ipykernel install --user --name tensorflow312 --display-name 
# "Python 3.12 (TF)"
# Out:
#   Cell In[14], line 1
#     python -m ipykernel install --user --name tensorflow312 --display-name
#               ^
# SyntaxError: invalid syntax
